# %%
import couchdb
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json

# %%
###API ########################
ckey = ""
csecret = ""
atoken = ""
asecret = ""
#####################################

# %%
class listener(StreamListener):
    
    def on_data(self, data):
        dictTweet = json.loads(data)
        try:
            
            dictTweet["_id"] = str(dictTweet['id'])
            doc = db.save(dictTweet)
            print ("SAVED" + str(doc) +"=>" + str(data))
        except:
            print ("Already exists")
            pass
        return True
    
    def on_error(self, status):
        print (status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())

'''========couchdb'=========='''
server = couchdb.Server('http://Eduardo:Eduardo@localhost:5984/')  #('http://115.146.93.184:5984/')
try:
    db = server.create('juegosolimpicostwiter3')
except:
    db = server['juegosolimpicostwiter3']
    
'''===============LOCATIONS=============='''    

twitterStream.filter(locations=[-83.56,25.3,-79.6,30.24]) #Ubicacion de miami  
#twitterStream.filter(track=['fortnite','freefire'])
# Out:
# SAVED('1421250720037326858', '1-2b3cc3b54df7f2825bb978e50214dddf')=>{"created_at":"Fri Jul 30 23:25:51 +0000 2021","id":1421250720037326858,"id_str":"1421250720037326858","text":"@brittneefuckink Like yes. He giving me those teenage Chris brown vibes I use to have. \ud83d\ude02","display_text_range":[17,88],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":1421231718732812288,"in_reply_to_status_id_str":"1421231718732812288","in_reply_to_user_id":732748941561847808,"in_reply_to_user_id_str":"732748941561847808","in_reply_to_screen_name":"brittneefuckink","user":{"id":242213414,"id_str":"242213414","name":"Jade \ud83d\udc95","screen_name":"EvonneJada","location":"Orlando, FL","url":null,"description":"|26|IG:Evonne.Jada","translator_type":"none","protected":false,"verified":false,"followers_count":2126,"friends_count":553,"listed_count":6,"favourites_count":53845,"statuse
# ...

# %%
import couchdb
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json

# %%
###API ########################
ckey = "O7kLo13yGYQ46L1qSS4HXydPa"
csecret = "HlmfMzx2tbTR9HAnGeVAEWHhU4GCwiU8H8lOj03jsWPozXvE9h"
atoken = "1415817657669013507-xVOdXUn8mLQmt1P605VeglmsAoEIyR"
asecret = "UmJSzH1QmVYEETrrVSPsGKqFDTXOeiXVUb6qCTOTLUJ6u"
#####################################

# %%
class listener(StreamListener):
    
    def on_data(self, data):
        dictTweet = json.loads(data)
        try:
            
            dictTweet["_id"] = str(dictTweet['id'])
            doc = db.save(dictTweet)
            print ("SAVED" + str(doc) +"=>" + str(data))
        except:
            print ("Already exists")
            pass
        return True
    
    def on_error(self, status):
        print (status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())

'''========couchdb'=========='''
server = couchdb.Server('http://Eduardo:Eduardo@localhost:5984/')  #('http://115.146.93.184:5984/')
try:
    db = server.create('juegosolimpicostwiter2')
except:
    db = server['juegosolimpicostwiter2']
    
'''===============LOCATIONS=============='''    

twitterStream.filter(locations=[138.9569,35.193,140.8301,36.7006]) #Ubicacion de tokyo  
#twitterStream.filter(track=['fortnite','freefire'])
# Out:
# SAVED('1421252557679206400', '1-5de5c5a0e8ab5e3667a330e58809bd7c')=>{"created_at":"Fri Jul 30 23:33:10 +0000 2021","id":1421252557679206400,"id_str":"1421252557679206400","text":"#Nowplaying \u6a0b\u53e3\u4e86\u4e00\u306e\u300e\u5e30\u3063\u3066\u304d\u305f\u5922\u65c5\u4eba\u300f 20210725 - \u6a0b\u53e3\u4e86\u4e00 (\u6a0b\u53e3\u4e86\u4e00\u306e\u300e\u5e30\u3063\u3066\u304d\u305f\u5922\u65c5\u4eba\u300f) https:\/\/t.co\/RxFohQwH1N","display_text_range":[0,61],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":45069801,"id_str":"45069801","name":"\u6559\u6388","screen_name":"kyoujuhs","location":"\u6771\u4eac\u90fd\u5317\u533a","url":"https:\/\/twpro.jp\/kyoujuhs","description":"\uff34\uff22\uff33\u30e9\u30b8\u30aa\u3068\u5bff\u6843
# ...

# %%
import couchdb
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json

# %%
###API ########################
ckey = "O7kLo13yGYQ46L1qSS4HXydPa"
csecret = "HlmfMzx2tbTR9HAnGeVAEWHhU4GCwiU8H8lOj03jsWPozXvE9h"
atoken = "1415817657669013507-xVOdXUn8mLQmt1P605VeglmsAoEIyR"
asecret = "UmJSzH1QmVYEETrrVSPsGKqFDTXOeiXVUb6qCTOTLUJ6u"
#####################################

# %%
class listener(StreamListener):
    
    def on_data(self, data):
        dictTweet = json.loads(data)
        try:
            
            dictTweet["_id"] = str(dictTweet['id'])
            doc = db.save(dictTweet)
            print ("SAVED" + str(doc) +"=>" + str(data))
        except:
            print ("Already exists")
            pass
        return True
    
    def on_error(self, status):
        print (status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())

'''========couchdb'=========='''
server = couchdb.Server('http://Eduardo:Eduardo@localhost:5984/')  #('http://115.146.93.184:5984/')
try:
    db = server.create('juegosolimpicostwiter1')
except:
    db = server['juegosolimpicostwiter1']
    
'''===============LOCATIONS=============='''    

twitterStream.filter(locations=[-79.2685,-1.3683,-77.3954,0.4333]) #Ubicacion de Quito  
#twitterStream.filter(track=['fortnite','freefire'])
# Out:
# SAVED('1421253525879894017', '1-5aeb3b97cf7ce4730ba53b5b5e2e9f20')=>{"created_at":"Fri Jul 30 23:37:00 +0000 2021","id":1421253525879894017,"id_str":"1421253525879894017","text":"@dennisllerena11 Usar a la justicia no es democracia estimado Dennis.","display_text_range":[17,69],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":1421238712336257024,"in_reply_to_status_id_str":"1421238712336257024","in_reply_to_user_id":2160084621,"in_reply_to_user_id_str":"2160084621","in_reply_to_screen_name":"dennisllerena11","user":{"id":217675616,"id_str":"217675616","name":"FRANCO FERN\u00c1NDEZ S.","screen_name":"francofer1","location":"Quito + Ecuador","url":"http:\/\/www.facebook.com\/francofernandezs","description":"Emprendedor \/ Escritor @NochesDeAurora \/ Activista Laboral \/ P @YSiTePasaATi_CT \/ Atleta \/ Speaker: PUCE, UCE, ESPE, UTI, UDLH, UDP, ISTL \/\nVP @ColoniaQuitoZ"
# ...
